# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("steady_clock/batterystatus.csv")
df
# Out:
#       TCP Received  Converted  IPC bytes out  Avg. bytes/msg  \
# 0                1          1            296             296
# 1                1          1            296             296
# 2                1          1            296             296
# 3                1          1            296             296
# 4                1          1            296             296
# ...            ...        ...            ...             ...
# 8188             1          1            296             296
# 8189             1          1            296             296
# 8190             1          1            296             296
# 8191             1          1            296             296
# 8192             1          1            296             296
#
#       Avg. convert time  Avg. thread time  IPC messages  Avg. publish time  \
# 0              0.001267          0.127755             1           0.030281
# 1              0.001147          0.037690             1           0.006100
# 2              0.001303          0.026536             1           0.006502
# 3              0.001281          0.025619             1           0.005710
# 4              0.001268          0.027373             1           0.006374
# ...                 ...               ...           ...                ...
# 8188           0.001184          0.012368             1           0.002965
# 8189           0.000772          0.013673             1           0.002792
# 8190           0.001128          0.012852             1           0.003076
# 8191           0.001228          0.012431             1           0.003216
# 8192           0.001261          0.012310             1           0.002781
#
#       Publish thread time  First latency
# 0                0.030284       0.086811
# 1                0.006103       0.025719
# 2                0.006504       0.013903
# 3                0.005713       0.013772
# 4                0.006377       0.014720
# ...                   ...            ...
# 8188             0.002968       0.003378
# 8189             0.004621       0.000828
# 8190             0.003079       0.003666
# 8191             0.003220       0.003232
# 8192             0.002786       0.003490
#
# [8193 rows x 10 columns]

# %%
y_lat = df['First latency']
y_conv = df['Avg. convert time']
y_pub = df['Avg. publish time']

# JSON to Arrow conversion is included in y_lat
y_total = y_lat + y_pub

num_rows = df.count()[0]
x = np.arange(0, num_rows)

# %%
plt.rcParams.update({"text.usetex": True})
plt.rcParams.update({"font.size": '15'})

background = '#f5ebdf'
colors = ['#000000', '#c0a040', '#007e80', '#e06055', '#3f5fbf', '#d275de', '#7bb144', '#888888']

fig = plt.figure(figsize=(16, 8))
ax_left = fig.add_subplot(1, 6, (1, 5))
ax_right = fig.add_subplot(1, 6, 6, sharey=ax_left)

ax_left.scatter(x=x, y=y_lat, s=2, c=colors[2], label='First TCP packet to Pulsar send()')
ax_left.scatter(x=x, y=y_conv, s=2, c=colors[3], label='JSON to Arrow')
ax_left.scatter(x=x, y=y_pub, s=2, c=colors[4], label='Pulsar send()')
ax_left.scatter(x=x, y=y_total, s=2, c=colors[1], label='Total')

sns.histplot(ax=ax_right, y=y_lat, color=colors[2])

ax_left.hlines(df["First latency"].mean(), 0, num_rows, color=colors)

ax_left.grid(which='both')
ax_right.grid(which='both')

ax_left.set_ylabel('Time (s)')
ax_right.set_ylabel(None)
ax_left.set_xlabel('Experiment no.')

ax_left.set_facecolor(background)
ax_right.set_facecolor(background)

#ax_left.set_yscale('log')
ax_left.set_ylim([0, 0.02])

leg = ax_left.legend()
for h in leg.legendHandles:
    h._sizes = [30]

ax_left.set_title('Battery status')
    
fig.set_facecolor('white')
fig.tight_layout()

fig.savefig("battery.pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-19f312c67a6f> in <module>
#      14 ax_left.scatter(x=x, y=y_total, s=2, c=colors[1], label='Total')
#      15
# ---> 16 sns.histplot(ax=ax_right, y=y_all[0], color=colors[2])
#      17
#      18 ax_left.hlines(df["First latency"].mean(), 0, num_rows, color=colors)
#
# NameError: name 'y_all' is not defined
